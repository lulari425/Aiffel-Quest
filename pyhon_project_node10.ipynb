# %% [markdown]
# <a href="https://colab.research.google.com/github/lulari425/Aiffel_Quest/blob/main/pyhon_project_node10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 평가문항	상세기준
# 1. 프로젝트 1번에서 평행사변형, 사다리꼴 넓이를 구하는 메서드를 직접 작성할 수 있다.	self 인자를 잊지 않고 넣고, 변수를 알맞게 사용했다.

# 사각형 넓이를 구하는 클래스 완성!

class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')
            print(self.rect())
        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
            print(self.par())
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
            print(self.trape())
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        while True:
            try:
                width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
                break
            except ValueError:
                print("올바른 형식으로 입력해주세요. 예시: 가로,세로")
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        while True:
            try:
                lower, height = map(int, input('밑변, 높이를 입력하세요. 예시 : 밑변, 높이\n >>>').split(','))
                break
            except ValueError:
                print("올바른 형식으로 입력해주세요. 예시: 밑변, 높이")
        area = lower * height
        result = '평행사변형 넓이는 : ' + str(area)
        return result

    def trape(self):
        while True:
            try:
                lower, upper, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시 : 밑변, 윗변, 높이\n >>>').split(','))
                break
            except ValueError:
                print("올바른 형식으로 입력해주세요. 예시: 밑변, 윗변, 높이")
        area = (lower + upper) * height / 2
        result = '사다리꼴 넓이는 : ' + str(area)
        return result

a = Square()  # 객체 생성 & 2, 3을 각각 입력해 봅시다.
# # 평형사변형의 넓이
# a.par()  # 3,2를 입력했을 때 넓이가 6이 나와야 합니다.
# # 사다리꼴의 넓이
# a.trape()  # 3,4,5 을 입력했을 때 넓이가 17.5이 나와야 합니다.
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>>3
# 사다리꼴 함수는 trape()입니다.
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변, 윗변, 높이
#  >>>2
# 올바른 형식으로 입력해주세요. 예시: 밑변, 윗변, 높이
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변, 윗변, 높이
#  >>>3,4,5
# 사다리꼴 넓이는 : 17.5

# %%
# 2. 프로젝트 2번에서 Kiosk 클래스를 생성하고, 주문, 추가 주문 메서드를 적절하게 구현할 수 있다.
# 3. 프로젝트 2번의 지불, 주문표 작성 메서드를 적절하게 구현할 수 있다.
# 각각의 메서드가 에러 없이, 정상적으로 동작하였다


# 문제 3-3. 클래스 업데이트
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요!

class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]
        self.order_menu = []
        self.order_price = []
        self.total_price = 0

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        while True :
            print()  # 줄 바꿈
            n = 0
            while n < 1 or len(self.menu) < n:
                n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

                # 메뉴판에 있는 음료 번호일때
                if 1 <= n & n <= len(self.menu):
                    self.price_sum = self.price[n-1]  # 선택 음료의 가격
                    self.order_menu.append(self.menu[n - 1])
                    self.order_price.append(self.price[n - 1])
                    self.total_price += self.price[n - 1]

                # 메뉴판에 없는 번호일 때
                else:
                    print("없는 메뉴입니다. 다시 주문해 주세요.")
                    continue

            # 음료 온도 물어보기
            t = 0  # 기본값을 넣어주고
            while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
                t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                # 문제 2-3. 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.
                # 힌트: if문을 활용해보세요.
                if t == 1:
                    self.temp = "HOT"
                elif t == 2:
                    self.temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.\n")
            # 문제 2-2의 답을 입력하세요.
            # 온도 속성을 추가한 주문 결과 출력
            self.order_menu[-1] = f'{self.temp} {self.order_menu[-1]}'
            print('주문 음료', self.temp,  self.order_menu[-1], ' : ',    self.order_price[-1] , '원')  # 온도 속성을 추가한 주문 결과 출력

            # 추가 주문 또는 지불
            add_more = input("추가 주문은 'y', 지불은 'n'을 입력하세요: ").lower()
            if add_more == 'n':
                break

    # 지불
    def pay(self):
        print(f'지불할 금액은 {self.total_price}원입니다.')
        payment_method = input("지불 수단을 선택하세요 (현금: 'cash' or 1, 카드: 'card' or 2) : ").lower()

        if payment_method == 'cash' or payment_method == '1':
            print('직원을 호출하겠습니다.')
        elif payment_method == 'card' or payment_method == '2':
            print('IC칩 방향에 맞게 카드를 꽂아주세요.')
        else:
            print('다시 결제를 시도해 주세요.')



    # 주문서 출력
    def table(self):

        # 외곽
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        # 주문 상품명 : 해당 금액
        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ' : ', self.order_price[i])

        print('합계 금액 :', self.total_price)

        # 외곽
        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 주문 음료 ICE ICE mocha  :  3000 원
# 추가 주문은 'y', 지불은 'n'을 입력하세요: y
#
# 음료 번호를 입력하세요 : 4
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# 주문 음료 HOT HOT yuza_tea  :  2500 원
# 추가 주문은 'y', 지불은 'n'을 입력하세요: y
#
# 음료 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# 주문 음료 ICE ICE mocha  :  3000 원
# 추가 주문은 'y', 지불은 'n'을 입력하세요: n
# 지불할 금액은 8500원입니다.
# 지불 수단을 선택하세요 (현금: 'cash' or 1, 카드: 'card' or 2) : 1
# 직원을 호출하겠습니다.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE mocha  :  3000
# HOT yuza_tea  :  2500
# ICE mocha  :  3000
# 합계 금액 : 8500
# |                               |
# |                               |
# ...
